# %%
# !pip install pytorch-transformers skorch

import pandas as pd
import sys
import os
from google.colab import drive

drive.mount('/content/gdrive')
PROJECT_DIR = '/content/gdrive/My Drive/'
os.chdir(PROJECT_DIR)
sys.path.append(PROJECT_DIR)
# Out:
# ...
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from pretrain import pretrain
model = pretrain(num_train=1024, num_valid=256, max_epochs=10, train_bert=False)
# Out:
# Running on gpu
# epoch		train_loss	valid_loss	valid_acc	time
# ...
# 0		2.597		2.817		0.035		33.420
# 1		2.423		2.681		0.047		35.619
